# %%
# !pip3 install deepface

# %%
from deepface import DeepFace
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img_class = "Aaron_Peirsol"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Aaron_Peirsol_0002.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"

# %%
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:15<00:00,  3.78s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7cecaf3040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7cecd07670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7cebd99ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7ceb896c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:39<00:00, 39.34s/it]
# find function lasts  54.87894415855408  seconds

# %%
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# 0.9969825124988468 ** 1940

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.130922 % Found index: 1940

# %%
img_class = "Abdoulaye_Wade"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Abdoulaye_Wade_0002.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:16<00:00,  4.13s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c9059c1f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c9059cee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c8a6e4040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c8a6e4d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:38<00:00, 38.14s/it]
# find function lasts  55.184277057647705  seconds
# 0.9925990174349765 ** 2164

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.506549 % Found index: 2164

# %%
img_class = "Abdullah"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Abdullah_0003.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:17<00:00,  4.45s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c1d73a8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c1b543670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c1a5e5790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c1b7594c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:35<00:00, 35.16s/it]
# find function lasts  53.2524151802063  seconds
# 0.9982175829792139 ** 239

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.007984 % Found index: 239

# %%
img_class = "Anders_Ebbeson"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Anders_Ebbeson_0003.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:14<00:00,  3.59s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c1a687040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c1a687dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7baf65cee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c19d90c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:37<00:00, 37.54s/it]
# find function lasts  52.181222915649414  seconds

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.102434 % Found index: 239

# %%
img_class = "Anders_Fogh_Rasmussen"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Anders_Fogh_Rasmussen_0004.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:13<00:00,  3.47s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7b50104ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7bb03e5d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7b4feb35e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7b4a7cb310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:37<00:00, 37.46s/it]
# find function lasts  51.72702097892761  seconds
# 0.9976547933951394 ** 64

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.061744 % Found index: 64

# %%
img_class = "Andre_Agassi"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Andre_Agassi_0002.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:21<00:00,  5.30s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7ade6a8ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7ade6b0d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7ad9bc7e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7ade5cbb80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:36<00:00, 36.05s/it]
# find function lasts  57.71444392204285  seconds
# 0.9972118048629917 ** 164

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.102662 % Found index: 164

# %%
img_class = "Andrew_Weissmann"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Andrew_Weissmann_0003.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:15<00:00,  3.84s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7a70a96280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7a6a492040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7a7031aa60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7a69c9d790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:38<00:00, 38.79s/it]
# find function lasts  54.91068696975708  seconds
# 0.995302512225918 ** 878

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.235822 % Found index: 878

# %%
img_class = "Andy_Roddick"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Andy_Roddick_0013.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:15<00:00,  3.90s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7a07f41dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f79fa48ac10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f79fbd06d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f79fbd6da60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:38<00:00, 38.38s/it]
# find function lasts  54.51216220855713  seconds
# 0.9972574492490667 ** 436

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.101928 % Found index: 436

# %%
img_class = "Angela_Bassett"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Angela_Bassett_0005.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:12<00:00,  3.19s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7990811ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7a07f5bd30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f79904c55e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f798a31c160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:40<00:00, 40.58s/it]
# find function lasts  53.65886998176575  seconds
# 0.9969725576919597 ** 731

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.126660 % Found index: 731

# %%
img_class = "Larry_Coker"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Larry_Coker_0004.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:22<00:00,  5.53s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78bf1645e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78b9db44c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78bab525e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78bf1b5310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:39<00:00, 39.35s/it]
# find function lasts  62.16801309585571  seconds
# 0.9960153168609582 ** 1391

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.225376 % Found index: 1391

# %%
img_class = "Bashar_Assad"
img_path = "Desktop/data/lfw_masked/lfw_test/" + img_class + "/Bashar_Assad_0001.jpg"
db_path = "Desktop/data/lfw_masked/lfw_train"
df = DeepFace.find(img_path = img_path, db_path = db_path, enforce_detection = False, model_name = "Ensemble" )
for i in range(len(df)):
    if (df.identity.iloc[i].find(img_class) != -1):
        print(df.score.iloc[i], "**", i)
        index = i
        break
# Out:
# Loading VGG-Face:   0%|          | 0/4 [00:00<?, ?it/s]
# Ensemble learning enabled
# Loading DeepFace: 100%|██████████| 4/4 [00:15<00:00,  3.76s/it]
# WARNING: Representations for images in  Desktop/data/lfw_masked/lfw_train  folder were previously stored in  representations_ensemble.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# There are  13027  representations found in  representations_ensemble.pkl
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7861d4daf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7861bce8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f784c1641f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f784c164e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Analyzing: 100%|██████████| 1/1 [00:49<00:00, 49.37s/it]
# find function lasts  64.83245897293091  seconds
# 0.9972690195663974 ** 10

# %%
searching_image_path = img_path
img = cv2.imread(searching_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10,5))
plt.subplot(3, 1, 1)
plt.imshow(img)
plt.title("Searching Image : %s "  %(img_class ))

first_predicted_image_path = df.identity.iloc[0]
temp = first_predicted_image_path.split('/')[4]
result1 = df.score.iloc[0]
img = cv2.imread(first_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 2)
plt.imshow(img)
plt.title("First Predicted Person :%s (%f)" % (temp, result1))
true_predicted_image_path = df.identity.iloc[index]
temp = true_predicted_image_path.split('/')[4]
result2 = df.score.iloc[index]
img = cv2.imread(true_predicted_image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(3, 1, 3)
plt.imshow(img)
plt.title("True Predicted Person :%s (%f)" % (temp, result2))
error = (abs(result1-result2)/result1) * 100
plt.tight_layout()
plt.show()
print("Error : %f %s Found index: %d" %(error,"%",index))
# Out:
# Error : 0.097735 % Found index: 10
